# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Dataset 1

# %%
df1 = pd.read_csv('C:\\Users\\Niti\\NEXTHIKES DIGICROME\\Project 2\\dataset_1 - dataset_1.csv')

# %% [markdown]
# # head

# %%
df1.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
# 3        4  01-01-2011       1   0     1   3    False        6           1
# 4        5  01-01-2011       1   0     1   4    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24

# %% [markdown]
# # tail

# %%
df1.tail()
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 605  0.18
# 606  0.18
# 607  0.18
# 608  0.22
# 609  0.20

# %% [markdown]
# # number of rows and columns

# %%
df1.shape
# Out:
# (610, 10)

# %% [markdown]
# # dimension of dataset 1

# %%
df1.ndim
# Out:
# 2

# %% [markdown]
# # datatype of dataset 1

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    object
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), float64(1), int64(7), object(1)
# memory usage: 43.6+ KB

# %% [markdown]
# # summary of dataset 1

# %%
df1.describe()
# Out:
#           instant  season     yr   mnth          hr     weekday  weathersit  \
# count  610.000000   610.0  610.0  610.0  610.000000  610.000000  610.000000
# mean   305.500000     1.0    0.0    1.0   11.795082    2.977049    1.477049
# std    176.236111     0.0    0.0    0.0    6.852107    2.054943    0.643496
# min      1.000000     1.0    0.0    1.0    0.000000    0.000000    1.000000
# 25%    153.250000     1.0    0.0    1.0    6.000000    1.000000    1.000000
# 50%    305.500000     1.0    0.0    1.0   12.000000    3.000000    1.000000
# 75%    457.750000     1.0    0.0    1.0   18.000000    5.000000    2.000000
# max    610.000000     1.0    0.0    1.0   23.000000    6.000000    4.000000
#
#              temp
# count  610.000000
# mean     0.196885
# std      0.081304
# min      0.020000
# 25%      0.160000
# 50%      0.200000
# 75%      0.235000
# max      0.460000

# %%
df1.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'weathersit', 'temp'],
#       dtype='object')

# %% [markdown]
# # Date of the ride

# %%
df1['dteday']
# Out:
# 0      01-01-2011
# 1      01-01-2011
# 2      01-01-2011
# 3      01-01-2011
# 4      01-01-2011
#           ...
# 605    28-01-2011
# 606    28-01-2011
# 607    28-01-2011
# 608    28-01-2011
# 609    28-01-2011
# Name: dteday, Length: 610, dtype: object

# %%
df1.rename(columns = {'dteday' : 'Date of the ride'}, inplace = True)

# %%
df1
# Out:
#      instant Date of the ride  season  yr  mnth  hr  holiday  weekday  \
# 0          1       01-01-2011       1   0     1   0    False        6
# 1          2       01-01-2011       1   0     1   1    False        6
# 2          3       01-01-2011       1   0     1   2    False        6
# 3          4       01-01-2011       1   0     1   3    False        6
# 4          5       01-01-2011       1   0     1   4    False        6
# ..       ...              ...     ...  ..   ...  ..      ...      ...
# 605      606       28-01-2011       1   0     1  11    False        5
# 606      607       28-01-2011       1   0     1  12    False        5
# 607      608       28-01-2011       1   0     1  13    False        5
# 608      609       28-01-2011       1   0     1  14    False        5
# 609      610       28-01-2011       1   0     1  15    False        5
#
#      weathersit  temp
# 0             1  0.24
# 1             1  0.22
# 2             1  0.22
# 3             1  0.24
# ...

# %% [markdown]
# # Season 1 = Spring

# %%
df1['season'] = df1['season'].replace({1:'Spring'})

# %%
df1
# Out:
#      instant Date of the ride  season  yr  mnth  hr  holiday  weekday  \
# 0          1       01-01-2011  Spring   0     1   0    False        6
# 1          2       01-01-2011  Spring   0     1   1    False        6
# 2          3       01-01-2011  Spring   0     1   2    False        6
# 3          4       01-01-2011  Spring   0     1   3    False        6
# 4          5       01-01-2011  Spring   0     1   4    False        6
# ..       ...              ...     ...  ..   ...  ..      ...      ...
# 605      606       28-01-2011  Spring   0     1  11    False        5
# 606      607       28-01-2011  Spring   0     1  12    False        5
# 607      608       28-01-2011  Spring   0     1  13    False        5
# 608      609       28-01-2011  Spring   0     1  14    False        5
# 609      610       28-01-2011  Spring   0     1  15    False        5
#
#      weathersit  temp
# 0             1  0.24
# 1             1  0.22
# 2             1  0.22
# 3             1  0.24
# ...

# %% [markdown]
# # Season 2 = Summer

# %%
df1['season'] = df1['season'].replace({2:'Summer'})

# %%
df1
# Out:
#      instant Date of the ride  season  yr  mnth  hr  holiday  weekday  \
# 0          1       01-01-2011  Spring   0     1   0    False        6
# 1          2       01-01-2011  Spring   0     1   1    False        6
# 2          3       01-01-2011  Spring   0     1   2    False        6
# 3          4       01-01-2011  Spring   0     1   3    False        6
# 4          5       01-01-2011  Spring   0     1   4    False        6
# ..       ...              ...     ...  ..   ...  ..      ...      ...
# 605      606       28-01-2011  Spring   0     1  11    False        5
# 606      607       28-01-2011  Spring   0     1  12    False        5
# 607      608       28-01-2011  Spring   0     1  13    False        5
# 608      609       28-01-2011  Spring   0     1  14    False        5
# 609      610       28-01-2011  Spring   0     1  15    False        5
#
#      weathersit  temp
# 0             1  0.24
# 1             1  0.22
# 2             1  0.22
# 3             1  0.24
# ...

# %% [markdown]
# # Season 3 = Fall

# %%
df1['season'] = df1['season'].replace({3:'Fall'})

# %%
df1
# Out:
#      instant Date of the ride  season  yr  mnth  hr  holiday  weekday  \
# 0          1       01-01-2011  Spring   0     1   0    False        6
# 1          2       01-01-2011  Spring   0     1   1    False        6
# 2          3       01-01-2011  Spring   0     1   2    False        6
# 3          4       01-01-2011  Spring   0     1   3    False        6
# 4          5       01-01-2011  Spring   0     1   4    False        6
# ..       ...              ...     ...  ..   ...  ..      ...      ...
# 605      606       28-01-2011  Spring   0     1  11    False        5
# 606      607       28-01-2011  Spring   0     1  12    False        5
# 607      608       28-01-2011  Spring   0     1  13    False        5
# 608      609       28-01-2011  Spring   0     1  14    False        5
# 609      610       28-01-2011  Spring   0     1  15    False        5
#
#      weathersit  temp
# 0             1  0.24
# 1             1  0.22
# 2             1  0.22
# 3             1  0.24
# ...

# %% [markdown]
# # Season 4 = Winter

# %%
df1['season'] = df1['season'].replace({4:'Winter'})

# %%
df1
# Out:
#      instant Date of the ride  season  yr  mnth  hr  holiday  weekday  \
# 0          1       01-01-2011  Spring   0     1   0    False        6
# 1          2       01-01-2011  Spring   0     1   1    False        6
# 2          3       01-01-2011  Spring   0     1   2    False        6
# 3          4       01-01-2011  Spring   0     1   3    False        6
# 4          5       01-01-2011  Spring   0     1   4    False        6
# ..       ...              ...     ...  ..   ...  ..      ...      ...
# 605      606       28-01-2011  Spring   0     1  11    False        5
# 606      607       28-01-2011  Spring   0     1  12    False        5
# 607      608       28-01-2011  Spring   0     1  13    False        5
# 608      609       28-01-2011  Spring   0     1  14    False        5
# 609      610       28-01-2011  Spring   0     1  15    False        5
#
#      weathersit  temp
# 0             1  0.24
# 1             1  0.22
# 2             1  0.22
# 3             1  0.24
# ...

# %% [markdown]
# # unique values of season

# %%
df1['season'].unique()
# Out:
# array(['Spring'], dtype=object)

# %% [markdown]
# # Whether day is considered a Holiday

# %%
df1['holiday'] = df1['holiday'].replace({False:'Not a Holiday'})

# %%
df1
# Out:
#      instant Date of the ride  season  yr  mnth  hr        holiday  weekday  \
# 0          1       01-01-2011  Spring   0     1   0  Not a Holiday        6
# 1          2       01-01-2011  Spring   0     1   1  Not a Holiday        6
# 2          3       01-01-2011  Spring   0     1   2  Not a Holiday        6
# 3          4       01-01-2011  Spring   0     1   3  Not a Holiday        6
# 4          5       01-01-2011  Spring   0     1   4  Not a Holiday        6
# ..       ...              ...     ...  ..   ...  ..            ...      ...
# 605      606       28-01-2011  Spring   0     1  11  Not a Holiday        5
# 606      607       28-01-2011  Spring   0     1  12  Not a Holiday        5
# 607      608       28-01-2011  Spring   0     1  13  Not a Holiday        5
# 608      609       28-01-2011  Spring   0     1  14  Not a Holiday        5
# 609      610       28-01-2011  Spring   0     1  15  Not a Holiday        5
#
#      weathersit  temp
# 0             1  0.24
# ...

# %%
df1['holiday'] = df1['holiday'].replace({True:'Holiday'})

# %%
df1
# Out:
#      instant Date of the ride  season  yr  mnth  hr        holiday  weekday  \
# 0          1       01-01-2011  Spring   0     1   0  Not a Holiday        6
# 1          2       01-01-2011  Spring   0     1   1  Not a Holiday        6
# 2          3       01-01-2011  Spring   0     1   2  Not a Holiday        6
# 3          4       01-01-2011  Spring   0     1   3  Not a Holiday        6
# 4          5       01-01-2011  Spring   0     1   4  Not a Holiday        6
# ..       ...              ...     ...  ..   ...  ..            ...      ...
# 605      606       28-01-2011  Spring   0     1  11  Not a Holiday        5
# 606      607       28-01-2011  Spring   0     1  12  Not a Holiday        5
# 607      608       28-01-2011  Spring   0     1  13  Not a Holiday        5
# 608      609       28-01-2011  Spring   0     1  14  Not a Holiday        5
# 609      610       28-01-2011  Spring   0     1  15  Not a Holiday        5
#
#      weathersit  temp
# 0             1  0.24
# ...

# %% [markdown]
# # unique values of holiday

# %%
df1['holiday'].unique()
# Out:
# array(['Not a Holiday', 'Holiday'], dtype=object)

# %% [markdown]
# # working day - whether the day is neither a weekend not a holiday

# %%
df1[(df1['weekday'] >= 6)]
# Out:
#      instant Date of the ride  season  yr  mnth  hr        holiday  weekday  \
# 0          1       01-01-2011  Spring   0     1   0  Not a Holiday        6
# 1          2       01-01-2011  Spring   0     1   1  Not a Holiday        6
# 2          3       01-01-2011  Spring   0     1   2  Not a Holiday        6
# 3          4       01-01-2011  Spring   0     1   3  Not a Holiday        6
# 4          5       01-01-2011  Spring   0     1   4  Not a Holiday        6
# ..       ...              ...     ...  ..   ...  ..            ...      ...
# 497      498       22-01-2011  Spring   0     1  19  Not a Holiday        6
# 498      499       22-01-2011  Spring   0     1  20  Not a Holiday        6
# 499      500       22-01-2011  Spring   0     1  21  Not a Holiday        6
# 500      501       22-01-2011  Spring   0     1  22  Not a Holiday        6
# 501      502       22-01-2011  Spring   0     1  23  Not a Holiday        6
#
#      weathersit  temp
# 0             1  0.24
# ...

# %%
len(df1[(df1['weekday'] >= 6)])
# Out:
# 95

# %%
df1[(df1['weekday'] >= 6)].count()
# Out:
# instant             95
# Date of the ride    95
# season              95
# yr                  95
# mnth                95
# hr                  95
# holiday             95
# weekday             95
# weathersit          95
# temp                95
# dtype: int64

# %%
df1['weekday'] = df1['weekday'].apply(lambda x: 'Working day' if x>=6 else 'Weekend or Holiday')

# %%
df1
# Out:
#      instant Date of the ride  season  yr  mnth  hr        holiday  \
# 0          1       01-01-2011  Spring   0     1   0  Not a Holiday
# 1          2       01-01-2011  Spring   0     1   1  Not a Holiday
# 2          3       01-01-2011  Spring   0     1   2  Not a Holiday
# 3          4       01-01-2011  Spring   0     1   3  Not a Holiday
# 4          5       01-01-2011  Spring   0     1   4  Not a Holiday
# ..       ...              ...     ...  ..   ...  ..            ...
# 605      606       28-01-2011  Spring   0     1  11  Not a Holiday
# 606      607       28-01-2011  Spring   0     1  12  Not a Holiday
# 607      608       28-01-2011  Spring   0     1  13  Not a Holiday
# 608      609       28-01-2011  Spring   0     1  14  Not a Holiday
# 609      610       28-01-2011  Spring   0     1  15  Not a Holiday
#
#                 weekday  weathersit  temp
# 0           Working day           1  0.24
# 1           Working day           1  0.22
# ...

# %% [markdown]
# # unique values of weekday

# %%
df1['weekday'].unique()
# Out:
# array(['Working day', 'Weekend or Holiday'], dtype=object)

# %% [markdown]
# # weather 1: clear, few clouds, partly cloudy

# %%
df1[(df1['weathersit'] == 1)]
# Out:
#      instant Date of the ride  season  yr  mnth  hr        holiday  \
# 0          1       01-01-2011  Spring   0     1   0  Not a Holiday
# 1          2       01-01-2011  Spring   0     1   1  Not a Holiday
# 2          3       01-01-2011  Spring   0     1   2  Not a Holiday
# 3          4       01-01-2011  Spring   0     1   3  Not a Holiday
# 4          5       01-01-2011  Spring   0     1   4  Not a Holiday
# ..       ...              ...     ...  ..   ...  ..            ...
# 590      591       27-01-2011  Spring   0     1  19  Not a Holiday
# 591      592       27-01-2011  Spring   0     1  20  Not a Holiday
# 592      593       27-01-2011  Spring   0     1  21  Not a Holiday
# 593      594       27-01-2011  Spring   0     1  22  Not a Holiday
# 594      595       27-01-2011  Spring   0     1  23  Not a Holiday
#
#                 weekday  weathersit  temp
# 0           Working day           1  0.24
# 1           Working day           1  0.22
# ...

# %%
len(df1[(df1['weathersit'] == 1)])
# Out:
# 368

# %%
df1['weathersit'] = df1['weathersit'].replace({1: 'Clear, Few clouds, Partly cloudy'})

# %%
df1
# Out:
#      instant Date of the ride  season  yr  mnth  hr        holiday  \
# 0          1       01-01-2011  Spring   0     1   0  Not a Holiday
# 1          2       01-01-2011  Spring   0     1   1  Not a Holiday
# 2          3       01-01-2011  Spring   0     1   2  Not a Holiday
# 3          4       01-01-2011  Spring   0     1   3  Not a Holiday
# 4          5       01-01-2011  Spring   0     1   4  Not a Holiday
# ..       ...              ...     ...  ..   ...  ..            ...
# 605      606       28-01-2011  Spring   0     1  11  Not a Holiday
# 606      607       28-01-2011  Spring   0     1  12  Not a Holiday
# 607      608       28-01-2011  Spring   0     1  13  Not a Holiday
# 608      609       28-01-2011  Spring   0     1  14  Not a Holiday
# 609      610       28-01-2011  Spring   0     1  15  Not a Holiday
#
#                 weekday                        weathersit  temp
# 0           Working day  Clear, Few clouds, Partly cloudy  0.24
# ...

# %% [markdown]
# # weather 2: Mist+Cloudy, Mist+Broken clouds, Mist+Few clouds, Mist

# %%
df1[(df1['weathersit'] == 2)]
# Out:
#      instant Date of the ride  season  yr  mnth  hr        holiday  \
# 5          6       01-01-2011  Spring   0     1   5  Not a Holiday
# 13        14       01-01-2011  Spring   0     1  13  Not a Holiday
# 14        15       01-01-2011  Spring   0     1  14  Not a Holiday
# 15        16       01-01-2011  Spring   0     1  15  Not a Holiday
# 16        17       01-01-2011  Spring   0     1  16  Not a Holiday
# ..       ...              ...     ...  ..   ...  ..            ...
# 599      600       28-01-2011  Spring   0     1   5  Not a Holiday
# 600      601       28-01-2011  Spring   0     1   6  Not a Holiday
# 601      602       28-01-2011  Spring   0     1   7  Not a Holiday
# 602      603       28-01-2011  Spring   0     1   8  Not a Holiday
# 609      610       28-01-2011  Spring   0     1  15  Not a Holiday
#
#                 weekday weathersit  temp
# 5           Working day          2  0.24
# 13          Working day          2  0.46
# ...

# %%
len(df1[(df1['weathersit'] == 2)])
# Out:
# 194

# %%
df1['weathersit'] = df1['weathersit'].replace({2: 'Mist+Cloudy, Mist+Broken clouds, Mist+Few clouds, Mist'})

# %%
df1
# Out:
#      instant Date of the ride  season  yr  mnth  hr        holiday  \
# 0          1       01-01-2011  Spring   0     1   0  Not a Holiday
# 1          2       01-01-2011  Spring   0     1   1  Not a Holiday
# 2          3       01-01-2011  Spring   0     1   2  Not a Holiday
# 3          4       01-01-2011  Spring   0     1   3  Not a Holiday
# 4          5       01-01-2011  Spring   0     1   4  Not a Holiday
# ..       ...              ...     ...  ..   ...  ..            ...
# 605      606       28-01-2011  Spring   0     1  11  Not a Holiday
# 606      607       28-01-2011  Spring   0     1  12  Not a Holiday
# 607      608       28-01-2011  Spring   0     1  13  Not a Holiday
# 608      609       28-01-2011  Spring   0     1  14  Not a Holiday
# 609      610       28-01-2011  Spring   0     1  15  Not a Holiday
#
#                 weekday                                         weathersit  \
# 0           Working day                   Clear, Few clouds, Partly cloudy
# ...

# %% [markdown]
# # weather 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain +Scattered clouds

# %%
df1[(df1['weathersit'] == 3)]
# Out:
#      instant Date of the ride  season  yr  mnth  hr        holiday  \
# 18        19       01-01-2011  Spring   0     1  18  Not a Holiday
# 19        20       01-01-2011  Spring   0     1  19  Not a Holiday
# 29        30       02-01-2011  Spring   0     1   6  Not a Holiday
# 31        32       02-01-2011  Spring   0     1   8  Not a Holiday
# 37        38       02-01-2011  Spring   0     1  14  Not a Holiday
# 38        39       02-01-2011  Spring   0     1  15  Not a Holiday
# 39        40       02-01-2011  Spring   0     1  16  Not a Holiday
# 142      143       07-01-2011  Spring   0     1   5  Not a Holiday
# 164      165       08-01-2011  Spring   0     1   3  Not a Holiday
# 165      166       08-01-2011  Spring   0     1   4  Not a Holiday
# 169      170       08-01-2011  Spring   0     1   8  Not a Holiday
# 170      171       08-01-2011  Spring   0     1   9  Not a Holiday
# 249      250       11-01-2011  Spring   0     1  18  Not a Holiday
# ...

# %%
len(df1[(df1['weathersit'] == 3)])
# Out:
# 47

# %%
df1['weathersit'] = df1['weathersit'].replace({3: 'Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain +Scattered clouds'})

# %%
df1
# Out:
#      instant Date of the ride  season  yr  mnth  hr        holiday  \
# 0          1       01-01-2011  Spring   0     1   0  Not a Holiday
# 1          2       01-01-2011  Spring   0     1   1  Not a Holiday
# 2          3       01-01-2011  Spring   0     1   2  Not a Holiday
# 3          4       01-01-2011  Spring   0     1   3  Not a Holiday
# 4          5       01-01-2011  Spring   0     1   4  Not a Holiday
# ..       ...              ...     ...  ..   ...  ..            ...
# 605      606       28-01-2011  Spring   0     1  11  Not a Holiday
# 606      607       28-01-2011  Spring   0     1  12  Not a Holiday
# 607      608       28-01-2011  Spring   0     1  13  Not a Holiday
# 608      609       28-01-2011  Spring   0     1  14  Not a Holiday
# 609      610       28-01-2011  Spring   0     1  15  Not a Holiday
#
#                 weekday                                         weathersit  \
# 0           Working day                   Clear, Few clouds, Partly cloudy
# ...

# %% [markdown]
# # weather 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog

# %%
df1[(df1['weathersit'] == 4)]
# Out:
#      instant Date of the ride  season  yr  mnth  hr        holiday  \
# 585      586       26-01-2011  Spring   0     1  16  Not a Holiday
#
#                 weekday weathersit  temp
# 585  Weekend or Holiday          4  0.22

# %%
len(df1[(df1['weathersit'] == 4)])
# Out:
# 1

# %%
df1['weathersit'] = df1['weathersit'].replace({4: 'Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog'})

# %%
df1
# Out:
#      instant Date of the ride  season  yr  mnth  hr        holiday  \
# 0          1       01-01-2011  Spring   0     1   0  Not a Holiday
# 1          2       01-01-2011  Spring   0     1   1  Not a Holiday
# 2          3       01-01-2011  Spring   0     1   2  Not a Holiday
# 3          4       01-01-2011  Spring   0     1   3  Not a Holiday
# 4          5       01-01-2011  Spring   0     1   4  Not a Holiday
# ..       ...              ...     ...  ..   ...  ..            ...
# 605      606       28-01-2011  Spring   0     1  11  Not a Holiday
# 606      607       28-01-2011  Spring   0     1  12  Not a Holiday
# 607      608       28-01-2011  Spring   0     1  13  Not a Holiday
# 608      609       28-01-2011  Spring   0     1  14  Not a Holiday
# 609      610       28-01-2011  Spring   0     1  15  Not a Holiday
#
#                 weekday                                         weathersit  \
# 0           Working day                   Clear, Few clouds, Partly cloudy
# ...

# %% [markdown]
# # unique values of weather situation

# %%
df1['weathersit'].unique()
# Out:
# array(['Clear, Few clouds, Partly cloudy',
#        'Mist+Cloudy, Mist+Broken clouds, Mist+Few clouds, Mist',
#        'Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain +Scattered clouds',
#        'Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog'],
#       dtype=object)

# %%
df1.rename(columns={'weathersit': 'Weather situation'}, inplace = True)

# %% [markdown]
# # temp - "feels like" temperature in Celsius

# %%
df1['temp']
# Out:
# 0      0.24
# 1      0.22
# 2      0.22
# 3      0.24
# 4      0.24
#        ...
# 605    0.18
# 606    0.18
# 607    0.18
# 608    0.22
# 609    0.20
# Name: temp, Length: 610, dtype: float64

# %%
df1['temp'] = df1['temp'].apply(lambda x: f'feels like {int(x*100)} degree celsius')

# %%
df1
# Out:
#      instant Date of the ride  season  yr  mnth  hr        holiday  \
# 0          1       01-01-2011  Spring   0     1   0  Not a Holiday
# 1          2       01-01-2011  Spring   0     1   1  Not a Holiday
# 2          3       01-01-2011  Spring   0     1   2  Not a Holiday
# 3          4       01-01-2011  Spring   0     1   3  Not a Holiday
# 4          5       01-01-2011  Spring   0     1   4  Not a Holiday
# ..       ...              ...     ...  ..   ...  ..            ...
# 605      606       28-01-2011  Spring   0     1  11  Not a Holiday
# 606      607       28-01-2011  Spring   0     1  12  Not a Holiday
# 607      608       28-01-2011  Spring   0     1  13  Not a Holiday
# 608      609       28-01-2011  Spring   0     1  14  Not a Holiday
# 609      610       28-01-2011  Spring   0     1  15  Not a Holiday
#
#                 weekday                                  Weather situation  \
# 0           Working day                   Clear, Few clouds, Partly cloudy
# ...

# %% [markdown]
# # Drop unnecessary columns

# %%
df1.drop(['yr', 'mnth', 'hr'], axis=1, inplace = True)

# %%
df1
# Out:
#      instant Date of the ride  season        holiday             weekday  \
# 0          1       01-01-2011  Spring  Not a Holiday         Working day
# 1          2       01-01-2011  Spring  Not a Holiday         Working day
# 2          3       01-01-2011  Spring  Not a Holiday         Working day
# 3          4       01-01-2011  Spring  Not a Holiday         Working day
# 4          5       01-01-2011  Spring  Not a Holiday         Working day
# ..       ...              ...     ...            ...                 ...
# 605      606       28-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 606      607       28-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 607      608       28-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 608      609       28-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 609      610       28-01-2011  Spring  Not a Holiday  Weekend or Holiday
#
#                                      Weather situation  \
# ...

# %% [markdown]
# # Missing values of dataset 1

# %%
df1.isnull().sum()
# Out:
# instant              0
# Date of the ride     0
# season               0
# holiday              0
# weekday              0
# Weather situation    0
# temp                 0
# dtype: int64

# %% [markdown]
# # Dataset 2

# %%
df2 = pd.read_csv('C:\\Users\\Niti\\NEXTHIKES DIGICROME\\Project 2\\dataset_2.xlsx - dataset_2.csv')

# %% [markdown]
# # head

# %%
df2.head()
# Out:
#    Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0           0        1  0.2879  0.81        0.0       3          13   16
# 1           1        2  0.2727  0.80        0.0       8          32   40
# 2           2        3  0.2727  0.80        0.0       5          27   32
# 3           3        4  0.2879  0.75        0.0       3          10   13
# 4           4        5  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# # tail

# %%
df2.tail()
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41

# %% [markdown]
# # number of rows and columns

# %%
df2.shape
# Out:
# (610, 8)

# %% [markdown]
# # datatype of dataset 2

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  610 non-null    int64
#  1   instant     610 non-null    int64
#  2   atemp       599 non-null    float64
#  3   hum         610 non-null    float64
#  4   windspeed   610 non-null    float64
#  5   casual      610 non-null    int64
#  6   registered  610 non-null    int64
#  7   cnt         610 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 38.3 KB

# %% [markdown]
# # summary of dataset 2

# %%
df2.describe()
# Out:
#        Unnamed: 0     instant       atemp         hum   windspeed      casual  \
# count  610.000000  610.000000  599.000000  610.000000  610.000000  610.000000
# mean   304.500000  305.500000    0.199935    0.562475    0.204851    4.501639
# std    176.236111  176.236111    0.078836    0.175440    0.121806    6.319945
# min      0.000000    1.000000    0.000000    0.210000    0.000000    0.000000
# 25%    152.250000  153.250000    0.151500    0.432500    0.104500    0.000000
# 50%    304.500000  305.500000    0.197000    0.520000    0.194000    2.000000
# 75%    456.750000  457.750000    0.242400    0.690000    0.283600    6.000000
# max    609.000000  610.000000    0.454500    1.000000    0.582100   47.000000
#
#        registered         cnt
# count  610.000000  610.000000
# mean    51.068852   55.570492
# std     47.021204   49.316802
# min      0.000000    1.000000
# 25%     14.000000   16.000000
# 50%     43.000000   47.000000
# 75%     70.000000   79.750000
# ...

# %% [markdown]
# # dimension of dataset 2

# %%
df2.ndim
# Out:
# 2

# %% [markdown]
# # humidity - relative humidity

# %%
import math

# %%
df2['hum'] = df2['hum'].apply(lambda x: f'{int(x*100)} %')

# %%
df2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  81 %     0.0000       3          13   16
# 1             1        2  0.2727  80 %     0.0000       8          32   40
# 2             2        3  0.2727  80 %     0.0000       5          27   32
# 3             3        4  0.2879  75 %     0.0000       3          10   13
# 4             4        5  0.2879  75 %     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  93 %     0.1045       0          30   30
# 606         606      607  0.2121  93 %     0.1045       1          28   29
# 607         607      608  0.2121  93 %     0.1045       0          31   31
# 608         608      609  0.2727  80 %     0.0000       2          36   38
# 609         609      610  0.2576  86 %     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
df2.rename(columns={'hum': 'Relative humidity'}, inplace = True)

# %% [markdown]
# # windspeed - wind speed

# %% [markdown]
# # unique values of windspeed

# %%
df2['windspeed'].unique()
# Out:
# array([0.    , 0.0896, 0.2537, 0.2836, 0.2985, 0.194 , 0.2239, 0.1343,
#        0.1642, 0.3284, 0.4478, 0.3582, 0.4179, 0.3881, 0.1045, 0.4925,
#        0.5522, 0.4627, 0.5224, 0.5821])

# %% [markdown]
# # central tendancy of windspeed

# %%
df2['windspeed'].mean()
# Out:
# 0.20485098360655737

# %%
df2['windspeed'].median()
# Out:
# 0.194

# %%
df2['windspeed'].mode()
# Out:
# 0    0.1642
# Name: windspeed, dtype: float64

# %% [markdown]
# # casual - number of non-registered user rentals initiated

# %% [markdown]
# # unique values of non-registered user rentals

# %%
df2['casual'].unique()
# Out:
# array([ 3,  8,  5,  0,  2,  1, 12, 26, 29, 47, 35, 40, 41, 15,  9,  6, 11,
#         4,  7, 16, 20, 19, 10, 13, 14, 18, 17, 21, 33, 23, 22, 24],
#       dtype=int64)

# %% [markdown]
# # central tendency of non-registered user rentals

# %%
df2['casual'].mean()
# Out:
# 4.501639344262295

# %%
df2['casual'].median()
# Out:
# 2.0

# %%
df2['casual'].mode()
# Out:
# 0    0
# Name: casual, dtype: int64

# %%
df2.rename(columns={'casual': 'Non-registered user rentals'}, inplace = True)

# %% [markdown]
# # registered - number of registered user rentals initiated

# %% [markdown]
# # unique values of registered user rentals

# %%
df2['registered'].unique()
# Out:
# array([ 13,  32,  27,  10,   1,   0,   2,   7,   6,  24,  30,  55,  47,
#         71,  70,  52,  26,  31,  25,  17,  16,   8,   4,  19,  46,  54,
#         73,  64,  67,  58,  43,  29,  20,   9,   5,   3,  63, 153,  81,
#         33,  41,  48,  53,  66, 146, 148, 102,  49,  11,  36,  92, 177,
#         98,  37,  50,  79,  68, 202, 179, 110,  34,  87, 192, 109,  74,
#         65,  85, 186, 166, 127,  82,  40,  18,  95, 216, 116,  42,  57,
#         78,  59, 163, 158,  51,  76, 190, 125, 178,  39,  14,  15,  56,
#         60,  90,  83,  69,  28,  35,  22,  12,  77,  44,  38,  75, 184,
#        174, 154,  97, 214,  45,  72, 130,  94, 139, 135, 197, 137, 141,
#        156, 117, 155, 134,  89,  80, 108,  61, 124, 132, 196, 107, 100,
#        247, 140,  86,  62, 207, 210, 159, 151, 119,  93,  23, 171, 145,
#        101,  21, 103, 233, 208, 218, 133], dtype=int64)

# %% [markdown]
# # central tendency of registered user rentals

# %%
df2['registered'].mean()
# Out:
# 51.06885245901639

# %%
df2['registered'].median()
# Out:
# 43.0

# %%
df2['registered'].mode()
# Out:
# 0    1
# Name: registered, dtype: int64

# %%
df2.rename(columns={'registered': 'Registered user rentals'}, inplace = True)

# %% [markdown]
# # count - number of total rentals

# %% [markdown]
# # unique values of total rentals

# %%
df2['cnt'].unique()
# Out:
# array([ 16,  40,  32,  13,   1,   2,   3,   8,  14,  36,  56,  84,  94,
#        106, 110,  93,  67,  35,  37,  34,  28,  39,  17,   9,   6,  20,
#         53,  70,  75,  59,  74,  76,  65,  30,  22,  31,   5,  64, 154,
#         88,  44,  51,  61,  77,  72, 157,  52,  12,   4, 179, 100,  42,
#         57,  78,  97,  63,  83, 212, 182, 112,  54,  48,  11,  33, 195,
#        115,  46,  79,  71,  62,  89, 190, 169, 132,  43,  19,  95, 219,
#        122,  45,  86, 172, 163,  69,  23,   7, 210, 134,  73,  50,  87,
#        187, 123,  15,  25,  98, 102,  55,  10,  49,  82,  92,  41,  38,
#        188,  47, 178, 155,  24,  18,  27,  99, 217, 130, 136,  29, 128,
#         81,  68, 139, 137, 202,  60, 162, 144, 158, 117,  90, 159, 101,
#        118, 129,  26, 104,  91, 113, 105,  21,  80, 125, 133, 197, 109,
#        161, 249, 143, 215, 185, 152, 126, 166, 120,  96, 103,  58, 116,
#        177, 184, 153, 108, 238, 222, 225, 146, 119], dtype=int64)

# %% [markdown]
# # central tendency of total rentals

# %%
df2['cnt'].mean()
# Out:
# 55.570491803278685

# %%
df2['cnt'].median()
# Out:
# 47.0

# %%
df2['cnt'].mode()
# Out:
# 0    1
# Name: cnt, dtype: int64

# %%
df2.rename(columns={'cnt': 'Total Rentals'}, inplace = True)

# %% [markdown]
# # Missing values of dataset 2

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0                      0
# instant                         0
# atemp                          11
# Relative humidity               0
# windspeed                       0
# Non-registered user rentals     0
# Registered user rentals         0
# Total Rentals                   0
# dtype: int64

# %%
df2['atemp'].mean()
# Out:
# 0.19993489148580967

# %%
df2['atemp'].fillna(df2['atemp'].mean(), inplace = True)

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0                     0
# instant                        0
# atemp                          0
# Relative humidity              0
# windspeed                      0
# Non-registered user rentals    0
# Registered user rentals        0
# Total Rentals                  0
# dtype: int64

# %% [markdown]
# # Dropping unnecessary columns

# %%
df2.drop('Unnamed: 0', axis=1, inplace = True)

# %% [markdown]
# # Merging Dataset 1 and Dataset 2

# %%
df3 = pd.merge(df1, df2, on='instant', how='inner')

# %%
df3
# Out:
#      instant Date of the ride  season        holiday             weekday  \
# 0          1       01-01-2011  Spring  Not a Holiday         Working day
# 1          2       01-01-2011  Spring  Not a Holiday         Working day
# 2          3       01-01-2011  Spring  Not a Holiday         Working day
# 3          4       01-01-2011  Spring  Not a Holiday         Working day
# 4          5       01-01-2011  Spring  Not a Holiday         Working day
# ..       ...              ...     ...            ...                 ...
# 605      606       28-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 606      607       28-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 607      608       28-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 608      609       28-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 609      610       28-01-2011  Spring  Not a Holiday  Weekend or Holiday
#
#                                      Weather situation  \
# ...

# %%
df3.to_csv('merged dataset.csv')

# %% [markdown]
# # Dataset 3

# %%
df4 = pd.read_csv('C:\\Users\\Niti\\NEXTHIKES DIGICROME\\Project 2\\dataset_3 - dataset_3.csv')

# %% [markdown]
# # head

# %%
df4.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0      611  28-01-2011       1   0     1  16    False        5           1
# 1      612  28-01-2011       1   0     1  17    False        5           1
# 2      613  28-01-2011       1   0     1  18    False        5           1
# 3      614  28-01-2011       1   0     1  19    False        5           2
# 4      615  28-01-2011       1   0     1  20    False        5           2
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.22  0.2727  0.80     0.0000      10          70   80
# 1  0.24  0.2424  0.75     0.1343       2         147  149
# 2  0.24  0.2273  0.75     0.1940       2         107  109
# 3  0.24  0.2424  0.75     0.1343       5          84   89
# 4  0.24  0.2273  0.70     0.1940       1          61   62

# %% [markdown]
# # tail

# %%
df4.tail()
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 385      996  14-02-2011       1   0     2   3    False        1           1
# 386      997  14-02-2011       1   0     2   4    False        1           1
# 387      998  14-02-2011       1   0     2   5    False        1           1
# 388      999  14-02-2011       1   0     2   6    False        1           1
# 389     1000  14-02-2011       1   0     2   7    False        1           1
#
#      temp   atemp   hum  windspeed  casual  registered  cnt
# 385  0.34  0.3182  0.46     0.2239       1           1    2
# 386  0.32  0.3030  0.53     0.2836       0           2    2
# 387  0.32  0.3030  0.53     0.2836       0           3    3
# 388  0.34  0.3030  0.46     0.2985       1          25   26
# 389  0.34  0.3030  0.46     0.2985       2          96   98

# %% [markdown]
# # number of rows and columns

# %%
df4.shape
# Out:
# (390, 16)

# %% [markdown]
# # datatype

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     390 non-null    int64
#  1   dteday      390 non-null    object
#  2   season      390 non-null    int64
#  3   yr          390 non-null    int64
#  4   mnth        390 non-null    int64
#  5   hr          390 non-null    int64
#  6   holiday     390 non-null    bool
#  7   weekday     390 non-null    int64
#  8   weathersit  390 non-null    int64
#  9   temp        390 non-null    float64
#  10  atemp       390 non-null    float64
#  11  hum         390 non-null    float64
#  12  windspeed   390 non-null    float64
#  13  casual      390 non-null    int64
#  14  registered  390 non-null    int64
#  15  cnt         390 non-null    int64
# dtypes: bool(1), float64(4), int64(10), object(1)
# memory usage: 46.2+ KB

# %% [markdown]
# # summary

# %%
df4.describe()
# Out:
#            instant  season     yr        mnth          hr     weekday  \
# count   390.000000   390.0  390.0  390.000000  390.000000  390.000000
# mean    805.500000     1.0    0.0    1.800000   11.687179    2.989744
# std     112.727548     0.0    0.0    0.400514    6.980295    2.149884
# min     611.000000     1.0    0.0    1.000000    0.000000    0.000000
# 25%     708.250000     1.0    0.0    2.000000    6.000000    1.000000
# 50%     805.500000     1.0    0.0    2.000000   12.000000    3.000000
# 75%     902.750000     1.0    0.0    2.000000   18.000000    5.000000
# max    1000.000000     1.0    0.0    2.000000   23.000000    6.000000
#
#        weathersit        temp       atemp         hum   windspeed      casual  \
# count  390.000000  390.000000  390.000000  390.000000  390.000000  390.000000
# mean     1.484615    0.220000    0.230424    0.613769    0.179416    5.576923
# std      0.663805    0.073095    0.069455    0.202361    0.138551    9.317478
# ...

# %% [markdown]
# # dimension

# %%
df4.ndim
# Out:
# 2

# %% [markdown]
# # Date of the ride

# %%
df4.rename(columns = {'dteday' : 'Date of the ride'}, inplace = True)

# %%
df4
# Out:
#      instant Date of the ride  season  yr  mnth  hr  holiday  weekday  \
# 0        611       28-01-2011       1   0     1  16    False        5
# 1        612       28-01-2011       1   0     1  17    False        5
# 2        613       28-01-2011       1   0     1  18    False        5
# 3        614       28-01-2011       1   0     1  19    False        5
# 4        615       28-01-2011       1   0     1  20    False        5
# ..       ...              ...     ...  ..   ...  ..      ...      ...
# 385      996       14-02-2011       1   0     2   3    False        1
# 386      997       14-02-2011       1   0     2   4    False        1
# 387      998       14-02-2011       1   0     2   5    False        1
# 388      999       14-02-2011       1   0     2   6    False        1
# 389     1000       14-02-2011       1   0     2   7    False        1
#
#      weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# ...

# %% [markdown]
# # season 1 = Spring

# %%
df4['season'] = df4['season'].replace({1:'Spring'})

# %%
df4
# Out:
#      instant Date of the ride  season  yr  mnth  hr  holiday  weekday  \
# 0        611       28-01-2011  Spring   0     1  16    False        5
# 1        612       28-01-2011  Spring   0     1  17    False        5
# 2        613       28-01-2011  Spring   0     1  18    False        5
# 3        614       28-01-2011  Spring   0     1  19    False        5
# 4        615       28-01-2011  Spring   0     1  20    False        5
# ..       ...              ...     ...  ..   ...  ..      ...      ...
# 385      996       14-02-2011  Spring   0     2   3    False        1
# 386      997       14-02-2011  Spring   0     2   4    False        1
# 387      998       14-02-2011  Spring   0     2   5    False        1
# 388      999       14-02-2011  Spring   0     2   6    False        1
# 389     1000       14-02-2011  Spring   0     2   7    False        1
#
#      weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# ...

# %% [markdown]
# # Season 2 = Summer

# %%
df4['season'] = df4['season'].replace({2:'Summer'})

# %%
df4
# Out:
#      instant Date of the ride  season  yr  mnth  hr  holiday  weekday  \
# 0        611       28-01-2011  Spring   0     1  16    False        5
# 1        612       28-01-2011  Spring   0     1  17    False        5
# 2        613       28-01-2011  Spring   0     1  18    False        5
# 3        614       28-01-2011  Spring   0     1  19    False        5
# 4        615       28-01-2011  Spring   0     1  20    False        5
# ..       ...              ...     ...  ..   ...  ..      ...      ...
# 385      996       14-02-2011  Spring   0     2   3    False        1
# 386      997       14-02-2011  Spring   0     2   4    False        1
# 387      998       14-02-2011  Spring   0     2   5    False        1
# 388      999       14-02-2011  Spring   0     2   6    False        1
# 389     1000       14-02-2011  Spring   0     2   7    False        1
#
#      weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# ...

# %% [markdown]
# # Season 3 = Fall

# %%
df4['season'] = df4['season'].replace({3:'Fall'})

# %%
df4
# Out:
#      instant Date of the ride  season  yr  mnth  hr  holiday  weekday  \
# 0        611       28-01-2011  Spring   0     1  16    False        5
# 1        612       28-01-2011  Spring   0     1  17    False        5
# 2        613       28-01-2011  Spring   0     1  18    False        5
# 3        614       28-01-2011  Spring   0     1  19    False        5
# 4        615       28-01-2011  Spring   0     1  20    False        5
# ..       ...              ...     ...  ..   ...  ..      ...      ...
# 385      996       14-02-2011  Spring   0     2   3    False        1
# 386      997       14-02-2011  Spring   0     2   4    False        1
# 387      998       14-02-2011  Spring   0     2   5    False        1
# 388      999       14-02-2011  Spring   0     2   6    False        1
# 389     1000       14-02-2011  Spring   0     2   7    False        1
#
#      weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# ...

# %% [markdown]
# # Season 4 = Winter

# %%
df4['season'] = df4['season'].replace({4:'Winter'})

# %%
df4
# Out:
#      instant Date of the ride  season  yr  mnth  hr  holiday  weekday  \
# 0        611       28-01-2011  Spring   0     1  16    False        5
# 1        612       28-01-2011  Spring   0     1  17    False        5
# 2        613       28-01-2011  Spring   0     1  18    False        5
# 3        614       28-01-2011  Spring   0     1  19    False        5
# 4        615       28-01-2011  Spring   0     1  20    False        5
# ..       ...              ...     ...  ..   ...  ..      ...      ...
# 385      996       14-02-2011  Spring   0     2   3    False        1
# 386      997       14-02-2011  Spring   0     2   4    False        1
# 387      998       14-02-2011  Spring   0     2   5    False        1
# 388      999       14-02-2011  Spring   0     2   6    False        1
# 389     1000       14-02-2011  Spring   0     2   7    False        1
#
#      weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# ...

# %% [markdown]
# # Unique values of Season

# %%
df4['season'].unique()
# Out:
# array(['Spring'], dtype=object)

# %% [markdown]
# # Whether day is considered a holiday

# %%
df4['holiday'] = df4['holiday'].replace({False:'Not a Holiday'})

# %%
df4
# Out:
#      instant Date of the ride  season  yr  mnth  hr        holiday  weekday  \
# 0        611       28-01-2011  Spring   0     1  16  Not a Holiday        5
# 1        612       28-01-2011  Spring   0     1  17  Not a Holiday        5
# 2        613       28-01-2011  Spring   0     1  18  Not a Holiday        5
# 3        614       28-01-2011  Spring   0     1  19  Not a Holiday        5
# 4        615       28-01-2011  Spring   0     1  20  Not a Holiday        5
# ..       ...              ...     ...  ..   ...  ..            ...      ...
# 385      996       14-02-2011  Spring   0     2   3  Not a Holiday        1
# 386      997       14-02-2011  Spring   0     2   4  Not a Holiday        1
# 387      998       14-02-2011  Spring   0     2   5  Not a Holiday        1
# 388      999       14-02-2011  Spring   0     2   6  Not a Holiday        1
# 389     1000       14-02-2011  Spring   0     2   7  Not a Holiday        1
#
# ...

# %%
df4['holiday'] = df4['holiday'].replace({True:'Holiday'})

# %%
df4
# Out:
#      instant Date of the ride  season  yr  mnth  hr        holiday  weekday  \
# 0        611       28-01-2011  Spring   0     1  16  Not a Holiday        5
# 1        612       28-01-2011  Spring   0     1  17  Not a Holiday        5
# 2        613       28-01-2011  Spring   0     1  18  Not a Holiday        5
# 3        614       28-01-2011  Spring   0     1  19  Not a Holiday        5
# 4        615       28-01-2011  Spring   0     1  20  Not a Holiday        5
# ..       ...              ...     ...  ..   ...  ..            ...      ...
# 385      996       14-02-2011  Spring   0     2   3  Not a Holiday        1
# 386      997       14-02-2011  Spring   0     2   4  Not a Holiday        1
# 387      998       14-02-2011  Spring   0     2   5  Not a Holiday        1
# 388      999       14-02-2011  Spring   0     2   6  Not a Holiday        1
# 389     1000       14-02-2011  Spring   0     2   7  Not a Holiday        1
#
# ...

# %% [markdown]
# # Unique values of Holiday

# %%
df4['holiday'].unique()
# Out:
# array(['Not a Holiday'], dtype=object)

# %% [markdown]
# # working day - whether the day is neither a weekend not a holiday

# %%
df4[df4['weekday'] >= 6]
# Out:
#      instant Date of the ride  season  yr  mnth  hr        holiday  weekday  \
# 8        619       29-01-2011  Spring   0     1   0  Not a Holiday        6
# 9        620       29-01-2011  Spring   0     1   1  Not a Holiday        6
# 10       621       29-01-2011  Spring   0     1   2  Not a Holiday        6
# 11       622       29-01-2011  Spring   0     1   3  Not a Holiday        6
# 12       623       29-01-2011  Spring   0     1   4  Not a Holiday        6
# ..       ...              ...     ...  ..   ...  ..            ...      ...
# 354      965       12-02-2011  Spring   0     2  19  Not a Holiday        6
# 355      966       12-02-2011  Spring   0     2  20  Not a Holiday        6
# 356      967       12-02-2011  Spring   0     2  21  Not a Holiday        6
# 357      968       12-02-2011  Spring   0     2  22  Not a Holiday        6
# 358      969       12-02-2011  Spring   0     2  23  Not a Holiday        6
#
# ...

# %%
len(df4[df4['weekday'] >= 6])
# Out:
# 71

# %%
df4[df4['weekday'] >= 6].count()
# Out:
# instant             71
# Date of the ride    71
# season              71
# yr                  71
# mnth                71
# hr                  71
# holiday             71
# weekday             71
# weathersit          71
# temp                71
# atemp               71
# hum                 71
# windspeed           71
# casual              71
# registered          71
# cnt                 71
# dtype: int64

# %%
df4['weekday'] = df4['weekday'].apply(lambda x: 'Working day' if x>=6 else 'Weekend or Holiday')

# %%
df4
# Out:
#      instant Date of the ride  season  yr  mnth  hr        holiday  \
# 0        611       28-01-2011  Spring   0     1  16  Not a Holiday
# 1        612       28-01-2011  Spring   0     1  17  Not a Holiday
# 2        613       28-01-2011  Spring   0     1  18  Not a Holiday
# 3        614       28-01-2011  Spring   0     1  19  Not a Holiday
# 4        615       28-01-2011  Spring   0     1  20  Not a Holiday
# ..       ...              ...     ...  ..   ...  ..            ...
# 385      996       14-02-2011  Spring   0     2   3  Not a Holiday
# 386      997       14-02-2011  Spring   0     2   4  Not a Holiday
# 387      998       14-02-2011  Spring   0     2   5  Not a Holiday
# 388      999       14-02-2011  Spring   0     2   6  Not a Holiday
# 389     1000       14-02-2011  Spring   0     2   7  Not a Holiday
#
#                 weekday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0    Weekend or Holiday           1  0.22  0.2727  0.80     0.0000      10
# ...

# %% [markdown]
# # Unique values of weekday

# %%
df4['weekday'].unique()
# Out:
# array(['Weekend or Holiday', 'Working day'], dtype=object)

# %% [markdown]
# # weather 1: clear, few clouds, partly cloudy

# %%
df4[df4['weathersit'] == 1]
# Out:
#      instant Date of the ride  season  yr  mnth  hr        holiday  \
# 0        611       28-01-2011  Spring   0     1  16  Not a Holiday
# 1        612       28-01-2011  Spring   0     1  17  Not a Holiday
# 2        613       28-01-2011  Spring   0     1  18  Not a Holiday
# 6        617       28-01-2011  Spring   0     1  22  Not a Holiday
# 7        618       28-01-2011  Spring   0     1  23  Not a Holiday
# ..       ...              ...     ...  ..   ...  ..            ...
# 385      996       14-02-2011  Spring   0     2   3  Not a Holiday
# 386      997       14-02-2011  Spring   0     2   4  Not a Holiday
# 387      998       14-02-2011  Spring   0     2   5  Not a Holiday
# 388      999       14-02-2011  Spring   0     2   6  Not a Holiday
# 389     1000       14-02-2011  Spring   0     2   7  Not a Holiday
#
#                 weekday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0    Weekend or Holiday           1  0.22  0.2727  0.80     0.0000      10
# ...

# %%
len(df4[df4['weathersit'] == 1])
# Out:
# 238

# %%
df4['weathersit'] = df4['weathersit'].replace({1: 'Clear, Few clouds, Partly cloudy'})

# %%
df4
# Out:
#      instant Date of the ride  season  yr  mnth  hr        holiday  \
# 0        611       28-01-2011  Spring   0     1  16  Not a Holiday
# 1        612       28-01-2011  Spring   0     1  17  Not a Holiday
# 2        613       28-01-2011  Spring   0     1  18  Not a Holiday
# 3        614       28-01-2011  Spring   0     1  19  Not a Holiday
# 4        615       28-01-2011  Spring   0     1  20  Not a Holiday
# ..       ...              ...     ...  ..   ...  ..            ...
# 385      996       14-02-2011  Spring   0     2   3  Not a Holiday
# 386      997       14-02-2011  Spring   0     2   4  Not a Holiday
# 387      998       14-02-2011  Spring   0     2   5  Not a Holiday
# 388      999       14-02-2011  Spring   0     2   6  Not a Holiday
# 389     1000       14-02-2011  Spring   0     2   7  Not a Holiday
#
#                 weekday                        weathersit  temp   atemp   hum  \
# 0    Weekend or Holiday  Clear, Few clouds, Partly cloudy  0.22  0.2727  0.80
# ...

# %% [markdown]
# # weather 2: Mist+Cloudy, Mist+Broken clouds, Mist+Few clouds, Mist

# %%
df4[df4['weathersit'] == 2]
# Out:
#      instant Date of the ride  season  yr  mnth  hr        holiday  \
# 3        614       28-01-2011  Spring   0     1  19  Not a Holiday
# 4        615       28-01-2011  Spring   0     1  20  Not a Holiday
# 5        616       28-01-2011  Spring   0     1  21  Not a Holiday
# 17       628       29-01-2011  Spring   0     1  10  Not a Holiday
# 18       629       29-01-2011  Spring   0     1  11  Not a Holiday
# ..       ...              ...     ...  ..   ...  ..            ...
# 366      977       13-02-2011  Spring   0     2   8  Not a Holiday
# 367      978       13-02-2011  Spring   0     2   9  Not a Holiday
# 372      983       13-02-2011  Spring   0     2  14  Not a Holiday
# 373      984       13-02-2011  Spring   0     2  15  Not a Holiday
# 374      985       13-02-2011  Spring   0     2  16  Not a Holiday
#
#                 weekday weathersit  temp   atemp   hum  windspeed  casual  \
# 3    Weekend or Holiday          2  0.24  0.2424  0.75     0.1343       5
# ...

# %%
len(df4[df4['weathersit'] == 2])
# Out:
# 115

# %%
df4['weathersit'] = df4['weathersit'].replace({2: 'Mist+Cloudy, Mist+Broken clouds, Mist+Few clouds, Mist'})

# %%
df4
# Out:
#      instant Date of the ride  season  yr  mnth  hr        holiday  \
# 0        611       28-01-2011  Spring   0     1  16  Not a Holiday
# 1        612       28-01-2011  Spring   0     1  17  Not a Holiday
# 2        613       28-01-2011  Spring   0     1  18  Not a Holiday
# 3        614       28-01-2011  Spring   0     1  19  Not a Holiday
# 4        615       28-01-2011  Spring   0     1  20  Not a Holiday
# ..       ...              ...     ...  ..   ...  ..            ...
# 385      996       14-02-2011  Spring   0     2   3  Not a Holiday
# 386      997       14-02-2011  Spring   0     2   4  Not a Holiday
# 387      998       14-02-2011  Spring   0     2   5  Not a Holiday
# 388      999       14-02-2011  Spring   0     2   6  Not a Holiday
# 389     1000       14-02-2011  Spring   0     2   7  Not a Holiday
#
#                 weekday                                         weathersit  \
# 0    Weekend or Holiday                   Clear, Few clouds, Partly cloudy
# ...

# %% [markdown]
# # weather 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain +Scattered clouds

# %%
df4[df4['weathersit'] == 3]
# Out:
#      instant Date of the ride  season  yr  mnth  hr        holiday  \
# 74       685       31-01-2011  Spring   0     1  20  Not a Holiday
# 75       686       31-01-2011  Spring   0     1  21  Not a Holiday
# 82       693       01-02-2011  Spring   0     2   5  Not a Holiday
# 83       694       01-02-2011  Spring   0     2   6  Not a Holiday
# 84       695       01-02-2011  Spring   0     2   7  Not a Holiday
# 85       696       01-02-2011  Spring   0     2   8  Not a Holiday
# 100      711       01-02-2011  Spring   0     2  23  Not a Holiday
# 101      712       02-02-2011  Spring   0     2   0  Not a Holiday
# 102      713       02-02-2011  Spring   0     2   1  Not a Holiday
# 103      714       02-02-2011  Spring   0     2   2  Not a Holiday
# 104      715       02-02-2011  Spring   0     2   3  Not a Holiday
# 105      716       02-02-2011  Spring   0     2   4  Not a Holiday
# 106      717       02-02-2011  Spring   0     2   5  Not a Holiday
# ...

# %%
len(df4[df4['weathersit'] == 3])
# Out:
# 37

# %%
df4['weathersit'] = df4['weathersit'].replace({3: 'Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain +Scattered clouds'})

# %%
df4
# Out:
#      instant Date of the ride  season  yr  mnth  hr        holiday  \
# 0        611       28-01-2011  Spring   0     1  16  Not a Holiday
# 1        612       28-01-2011  Spring   0     1  17  Not a Holiday
# 2        613       28-01-2011  Spring   0     1  18  Not a Holiday
# 3        614       28-01-2011  Spring   0     1  19  Not a Holiday
# 4        615       28-01-2011  Spring   0     1  20  Not a Holiday
# ..       ...              ...     ...  ..   ...  ..            ...
# 385      996       14-02-2011  Spring   0     2   3  Not a Holiday
# 386      997       14-02-2011  Spring   0     2   4  Not a Holiday
# 387      998       14-02-2011  Spring   0     2   5  Not a Holiday
# 388      999       14-02-2011  Spring   0     2   6  Not a Holiday
# 389     1000       14-02-2011  Spring   0     2   7  Not a Holiday
#
#                 weekday                                         weathersit  \
# 0    Weekend or Holiday                   Clear, Few clouds, Partly cloudy
# ...

# %% [markdown]
# # weather 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog

# %%
df4[df4['weathersit'] == 4]
# Out:
# Empty DataFrame
# Columns: [instant, Date of the ride, season, yr, mnth, hr, holiday, weekday, weathersit, temp, atemp, hum, windspeed, casual, registered, cnt]
# Index: []

# %%
len(df4[df4['weathersit'] == 4])
# Out:
# 0

# %% [markdown]
# # unique values of weather situation

# %%
df4['weathersit'].unique()
# Out:
# array(['Clear, Few clouds, Partly cloudy',
#        'Mist+Cloudy, Mist+Broken clouds, Mist+Few clouds, Mist',
#        'Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain +Scattered clouds'],
#       dtype=object)

# %%
df4.rename(columns={'weathersit': 'Weather situation'}, inplace = True)

# %% [markdown]
# # temp - "feels like" temperature in Celsius

# %%
df4['temp']
# Out:
# 0      0.22
# 1      0.24
# 2      0.24
# 3      0.24
# 4      0.24
#        ...
# 385    0.34
# 386    0.32
# 387    0.32
# 388    0.34
# 389    0.34
# Name: temp, Length: 390, dtype: float64

# %%
df4['temp'] = df4['temp'].apply(lambda x: f'feels like {int(x*100)} degree celsius')

# %%
df4
# Out:
#      instant Date of the ride  season  yr  mnth  hr        holiday  \
# 0        611       28-01-2011  Spring   0     1  16  Not a Holiday
# 1        612       28-01-2011  Spring   0     1  17  Not a Holiday
# 2        613       28-01-2011  Spring   0     1  18  Not a Holiday
# 3        614       28-01-2011  Spring   0     1  19  Not a Holiday
# 4        615       28-01-2011  Spring   0     1  20  Not a Holiday
# ..       ...              ...     ...  ..   ...  ..            ...
# 385      996       14-02-2011  Spring   0     2   3  Not a Holiday
# 386      997       14-02-2011  Spring   0     2   4  Not a Holiday
# 387      998       14-02-2011  Spring   0     2   5  Not a Holiday
# 388      999       14-02-2011  Spring   0     2   6  Not a Holiday
# 389     1000       14-02-2011  Spring   0     2   7  Not a Holiday
#
#                 weekday                                  Weather situation  \
# 0    Weekend or Holiday                   Clear, Few clouds, Partly cloudy
# ...

# %% [markdown]
# # Drop unnecessary columns

# %%
df4.drop(['yr', 'mnth', 'hr'], axis=1, inplace = True)

# %%
df4
# Out:
#      instant Date of the ride  season        holiday             weekday  \
# 0        611       28-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 1        612       28-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 2        613       28-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 3        614       28-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 4        615       28-01-2011  Spring  Not a Holiday  Weekend or Holiday
# ..       ...              ...     ...            ...                 ...
# 385      996       14-02-2011  Spring  Not a Holiday  Weekend or Holiday
# 386      997       14-02-2011  Spring  Not a Holiday  Weekend or Holiday
# 387      998       14-02-2011  Spring  Not a Holiday  Weekend or Holiday
# 388      999       14-02-2011  Spring  Not a Holiday  Weekend or Holiday
# 389     1000       14-02-2011  Spring  Not a Holiday  Weekend or Holiday
#
#                                      Weather situation  \
# ...

# %% [markdown]
# # humidity - relative humidity

# %%
df4['hum'] = df4['hum'].apply(lambda x: f'{int(x*100)} %')

# %%
df4
# Out:
#      instant Date of the ride  season        holiday             weekday  \
# 0        611       28-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 1        612       28-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 2        613       28-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 3        614       28-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 4        615       28-01-2011  Spring  Not a Holiday  Weekend or Holiday
# ..       ...              ...     ...            ...                 ...
# 385      996       14-02-2011  Spring  Not a Holiday  Weekend or Holiday
# 386      997       14-02-2011  Spring  Not a Holiday  Weekend or Holiday
# 387      998       14-02-2011  Spring  Not a Holiday  Weekend or Holiday
# 388      999       14-02-2011  Spring  Not a Holiday  Weekend or Holiday
# 389     1000       14-02-2011  Spring  Not a Holiday  Weekend or Holiday
#
#                                      Weather situation  \
# ...

# %%
df4.rename(columns={'hum': 'Relative humidity'}, inplace = True)

# %%
df4
# Out:
#      instant Date of the ride  season        holiday             weekday  \
# 0        611       28-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 1        612       28-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 2        613       28-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 3        614       28-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 4        615       28-01-2011  Spring  Not a Holiday  Weekend or Holiday
# ..       ...              ...     ...            ...                 ...
# 385      996       14-02-2011  Spring  Not a Holiday  Weekend or Holiday
# 386      997       14-02-2011  Spring  Not a Holiday  Weekend or Holiday
# 387      998       14-02-2011  Spring  Not a Holiday  Weekend or Holiday
# 388      999       14-02-2011  Spring  Not a Holiday  Weekend or Holiday
# 389     1000       14-02-2011  Spring  Not a Holiday  Weekend or Holiday
#
#                                      Weather situation  \
# ...

# %% [markdown]
# # windspeed - wind speed

# %% [markdown]
# # Unique values of windspeed

# %%
df4['windspeed'].unique()
# Out:
# array([0.    , 0.1343, 0.194 , 0.3582, 0.2239, 0.1642, 0.1045, 0.0896,
#        0.2537, 0.2836, 0.3284, 0.2985, 0.3881, 0.5224, 0.5522, 0.4925,
#        0.4478, 0.4179, 0.4627, 0.5821])

# %% [markdown]
# # central tendancy of windspeed

# %%
df4['windspeed'].mean()
# Out:
# 0.17941589743589748

# %%
df4['windspeed'].median()
# Out:
# 0.1642

# %%
df4['windspeed'].mode()
# Out:
# 0    0.0
# Name: windspeed, dtype: float64

# %% [markdown]
# # casual - number of non-registered user rentals initiated

# %% [markdown]
# # Unique values of non-registered user rentals

# %%
df4['casual'].unique()
# Out:
# array([10,  2,  5,  1,  0,  3,  4, 12,  9, 22, 19,  6,  7, 13, 18, 14,  8,
#        15, 11, 28, 48, 47, 52, 42, 24, 16, 21, 17, 30, 27, 32, 26, 58, 62,
#        51, 40], dtype=int64)

# %% [markdown]
# # central tendency of non-registered user rentals

# %%
df4['casual'].mean()
# Out:
# 5.576923076923077

# %%
df4['casual'].median()
# Out:
# 3.0

# %%
df4['casual'].mode()
# Out:
# 0    0
# Name: casual, dtype: int64

# %%
df4.rename(columns={'casual': 'Non-registered user rentals'}, inplace = True)

# %% [markdown]
# # registered - number of registered user rentals initiated

# %% [markdown]
# # Unique values of registered user rentals

# %%
df4['registered'].unique()
# Out:
# array([ 70, 147, 107,  84,  61,  57,  26,  22,  20,  15,   5,   2,   4,
#         31,  34,  51,  60,  66,  56,  89,  98,  88,  82,  59,  52,  42,
#         35,  28,  30,  33,  10,   7,   1,   3,  11,  50,  87,  71, 104,
#         95,  46,  25,  19,  16,   6,   8,  37, 182, 112,  68,  62,  85,
#         41,  83, 155, 153, 108,  78,  53, 132, 114,  47,  49,  45, 172,
#        165, 105,  69,  64,   0,  17,  48, 154, 119,  74, 183, 175,  29,
#         39,  86, 184, 127,  55,  67,  43,  73, 170, 145,  92, 217, 124,
#         76,  81,  91, 195, 152, 102,  36,  12,   9,  63,  40,  21,  38,
#        126, 135, 130, 115,  97,  65,  14, 223,  54, 207, 123,  75, 236,
#        128,  44,  79, 151, 100, 198,  72, 157, 168,  99, 173, 121, 159,
#        110,  93,  23, 212, 111, 193,  94,  27,  13, 103,  90, 113, 122,
#        106,  32,  96], dtype=int64)

# %% [markdown]
# # central tendency of registered user rentals

# %%
df4['registered'].mean()
# Out:
# 57.0025641025641

# %%
df4['registered'].median()
# Out:
# 48.0

# %%
df4['registered'].mode()
# Out:
# 0    1
# Name: registered, dtype: int64

# %%
df4.rename(columns={'registered': 'Registered user rentals'}, inplace = True)

# %% [markdown]
# # count - number of total rentals

# %% [markdown]
# # unique values of total rentals

# %%
df4['cnt'].unique()
# Out:
# array([ 80, 149, 109,  89,  62,  58,  26,  23,  28,  20,  15,   8,   3,
#          2,   5,  34,  55,  64,  78,  65,  99, 120, 107,  91,  68,  43,
#         36,  32,  33,  29,  11,   1,  12,  38,  59,  97,  84, 122, 123,
#         77,  21,   7,  37,  72, 185, 112,  69,  48,  54,  86,  44, 161,
#        156, 111,  56,  17,  22,  52, 135, 116,  47,  51, 176, 168, 108,
#         74,  16,   4,  18,  49, 155,  61,  75,  63,  76, 103, 190, 182,
#         40,  39,  87, 188, 133,  60, 175, 147,  96,  41,  13, 220, 127,
#         82,  90, 205,  71,  46,  31,   9,  10,  83,  45, 117, 174, 157,
#        121,  27,  30,  95, 230, 118,  66,  50, 114, 216, 128,  88,  25,
#        100, 243, 152, 101, 199,  79, 166, 170,   6, 178,  35, 165, 160,
#         14,  24, 140, 110, 125, 211,  53, 145, 137, 105, 154, 162, 134,
#         98], dtype=int64)

# %% [markdown]
# # central tendency of total rentals

# %%
df4['cnt'].mean()
# Out:
# 62.57948717948718

# %%
df4['cnt'].median()
# Out:
# 52.0

# %%
df4['cnt'].mode()
# Out:
# 0    2
# Name: cnt, dtype: int64

# %%
df4.rename(columns={'cnt': 'Total Rentals'}, inplace = True)

# %% [markdown]
# # Missing values

# %%
df4.isnull().sum()
# Out:
# instant                        0
# Date of the ride               0
# season                         0
# holiday                        0
# weekday                        0
# Weather situation              0
# temp                           0
# atemp                          0
# Relative humidity              0
# windspeed                      0
# Non-registered user rentals    0
# Registered user rentals        0
# Total Rentals                  0
# dtype: int64

# %% [markdown]
# # Concatenate Datasets

# %%
Final_dataset = pd.concat([df3,df4])

# %%
Final_dataset
# Out:
#      instant Date of the ride  season        holiday             weekday  \
# 0          1       01-01-2011  Spring  Not a Holiday         Working day
# 1          2       01-01-2011  Spring  Not a Holiday         Working day
# 2          3       01-01-2011  Spring  Not a Holiday         Working day
# 3          4       01-01-2011  Spring  Not a Holiday         Working day
# 4          5       01-01-2011  Spring  Not a Holiday         Working day
# ..       ...              ...     ...            ...                 ...
# 385      996       14-02-2011  Spring  Not a Holiday  Weekend or Holiday
# 386      997       14-02-2011  Spring  Not a Holiday  Weekend or Holiday
# 387      998       14-02-2011  Spring  Not a Holiday  Weekend or Holiday
# 388      999       14-02-2011  Spring  Not a Holiday  Weekend or Holiday
# 389     1000       14-02-2011  Spring  Not a Holiday  Weekend or Holiday
#
#                     Weather situation                          temp   atemp  \
# ...

# %%
Final_dataset.isnull().sum()
# Out:
# instant                        0
# Date of the ride               0
# season                         0
# holiday                        0
# weekday                        0
# Weather situation              0
# temp                           0
# atemp                          0
# Relative humidity              0
# windspeed                      0
# Non-registered user rentals    0
# Registered user rentals        0
# Total Rentals                  0
# dtype: int64

# %% [markdown]
# # Outliers

# %%
Q1 = Final_dataset['Total Rentals'].quantile(0.25)
Q3 = Final_dataset['Total Rentals'].quantile(0.75)
IQR = Q3 - Q1
threshold = 1.5

# %%
outliers = Final_dataset[(Final_dataset['Total Rentals'] < Q1 - threshold*IQR) | (Final_dataset['Total Rentals'] > Q3 + threshold*IQR)]

# %%
outliers
# Out:
#      instant Date of the ride  season        holiday             weekday  \
# 85        86       04-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 99       100       05-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 108      109       05-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 122      123       06-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 145      146       07-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 154      155       07-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 217      218       10-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 239      240       11-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 285      286       13-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 415      416       19-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 424      425       19-01-2011  Spring  Not a Holiday  Weekend or Holiday
# 439      440       20-01-2011  Spring  Not a Holiday  Weekend or Holiday
# ...

# %% [markdown]
# # Removing Outliers

# %%
Final_dataset_no_outliers = Final_dataset.drop(outliers.index)

# %%
Final_dataset_no_outliers
# Out:
#      instant Date of the ride  season        holiday             weekday  \
# 0          1       01-01-2011  Spring  Not a Holiday         Working day
# 1          2       01-01-2011  Spring  Not a Holiday         Working day
# 2          3       01-01-2011  Spring  Not a Holiday         Working day
# 3          4       01-01-2011  Spring  Not a Holiday         Working day
# 4          5       01-01-2011  Spring  Not a Holiday         Working day
# ..       ...              ...     ...            ...                 ...
# 385      996       14-02-2011  Spring  Not a Holiday  Weekend or Holiday
# 386      997       14-02-2011  Spring  Not a Holiday  Weekend or Holiday
# 387      998       14-02-2011  Spring  Not a Holiday  Weekend or Holiday
# 388      999       14-02-2011  Spring  Not a Holiday  Weekend or Holiday
# 389     1000       14-02-2011  Spring  Not a Holiday  Weekend or Holiday
#
#                     Weather situation                          temp   atemp  \
# ...

# %%
Final_dataset_no_outliers.to_csv('Concatenated dataset.csv')

# %% [markdown]
# # Skewness and correlation of final data

# %%
skewness_rows = Final_dataset_no_outliers.skew()
# Out:
# C:\Users\Niti\AppData\Local\Temp\ipykernel_12496\3407028243.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   skewness_rows = Final_dataset_no_outliers.skew()

# %%
skewness
# Out:
# instant                       -0.000937
# atemp                          0.444680
# windspeed                      0.426677
# Non-registered user rentals    3.398152
# Registered user rentals        0.958823
# Total Rentals                  0.862599
# dtype: float64

# %%
skewness_col = Final_dataset_no_outliers.skew(axis=1)
# Out:
# C:\Users\Niti\AppData\Local\Temp\ipykernel_12496\861495835.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   skewness_col = Final_dataset_no_outliers.skew(axis=1)

# %%
skewness_col
# Out:
# 0      0.955459
# 1      0.948175
# 2      0.950531
# 3      0.755818
# 4      2.147588
#          ...
# 385    2.449476
# 386    2.449463
# 387    2.449427
# 388    2.444445
# 389    2.372532
# Length: 950, dtype: float64

# %%
correlation = Final_dataset_no_outliers.corr()
# Out:
# C:\Users\Niti\AppData\Local\Temp\ipykernel_12496\1952777257.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = Final_dataset_no_outliers.corr()

# %%
correlation
# Out:
#                               instant     atemp  windspeed  \
# instant                      1.000000  0.076653  -0.059535
# atemp                        0.076653  1.000000  -0.208905
# windspeed                   -0.059535 -0.208905   1.000000
# Non-registered user rentals  0.072659  0.423501   0.134121
# Registered user rentals      0.089503  0.152045   0.125274
# Total Rentals                0.094972  0.214464   0.138670
#
#                              Non-registered user rentals  \
# instant                                         0.072659
# atemp                                           0.423501
# windspeed                                       0.134121
# Non-registered user rentals                     1.000000
# Registered user rentals                         0.391153
# Total Rentals                                   0.535887
#
#                              Registered user rentals  Total Rentals
# instant                                     0.089503       0.094972
# ...

# %%
sns.heatmap(correlation)
# Out:
# <Axes: >
